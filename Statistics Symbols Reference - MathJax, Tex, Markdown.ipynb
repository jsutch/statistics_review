# %% [markdown]
# <img src="statistics_symbols1.jpg" width="400" height="200">
# <img src="statistics_symbols2.png" width="400" height="400">

# %% [markdown]
# **Statistics Symbols in MathJax and markdown**
#
#
# Double $$ formatting justifies to center.
#
# - x squared: ```$$x^2$$```
# $$x^2$$
#
# Single justifies to left:
# - x squared: ```$x^2$```
# $x^2$
# - x to the power of -3: ```$x^{-3}$```
# $x^{-3}$
# - x cubed: ```$x^{3}$```
# $x^{3}$
# - x sub-1: ```$ x_1 $```
# $ x_1 $
# - X factorial: x! (4! = 4 * 3 * 2 * 1)
#
#  x!
# - X bar (x hat) ```$ \bar{x} $```
# $ \bar{x} $
# - mu: ```$ \mu, M $```
# $ \mu, M $
# - sigma:```$$ \sigma, \Sigma $$```
# $ \sigma,\Sigma $
#
#
# ### Setting equations
# **The probability of getting (k) heads when flipping (n) coins:**
#
# ```
# \begin{equation*}
# P(E)   = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}
# ```
# $
# \begin{equation*}
# P(E)   = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}
# $
#
#
# **Division**
#
# ```
# $
# \begin{equation*}
# \frac{y X}{z U}
# \end{equation*}
# $```
#
# $
# \begin{equation*}
# \frac{y X}{z U}
# \end{equation*}
# $
#
# **Bayes Theorem**
# ```
# $ P(A|B) = \frac{P(B|A)P(A)}{P(B)} $
#
# $ P(A|B) = \frac{P(B|A)P(A)}{P(B|A)P(A) + P(B|not A)P(not A)} $
# ```
# $ P(A|B) = \frac{P(B|A)P(A)}{P(B)} $
#
# or
#
# $ P(A|B) = \frac{P(B|A)P(A)}{P(B|A)P(A) + P(B|not A)P(not A)} $
#
# **greater than or equal to/less than or equal to using \mathrel**
#
# ```
# $ x > y $
# $ x \bar{>} y $
# $ x \mathrel{\bar{<}} y $
# ```
# - $ x > y $
# - $ x \bar{>} y $
# - $ x \mathrel{\bar{<}} y $
#
# **using less then equals/greater than equals**
# ```
# $ a\leq b\geq c $
# ```
#
# - $ a\leq b\geq c $
#
# **Strike-throughs**
#
# Single Line
#
# ```$\require{enclose} \enclose{horizontalstrike}{(a+b)^2 = a^2 + 2ab + b^2}$```
#
# $\require{enclose} \enclose{horizontalstrike}{(a+b)^2 = a^2 + 2ab + b^2}$
#
#
# Various X-throughs:
#
# $\require{cancel} \cancel{2-2}$
#
# $\require{bcancel} \bcancel{2-2}$
#
# $\require{xcancel} \xcancel{2-2}$
#
# $\require{cancelto} \cancelto{0}{2-2}$

# %% [markdown]
# ## Greek Alphabet - upper and lower
#
# #### Greek Alphabet, lower and upper
#
# - **alpha** - $\alpha, A $
# - **beta** - $\beta, B $
# - **gamma** - $\gamma, \Gamma $
# - **delta** - $\delta, \Delta $
# - **epsilon** - $\epsilon, E $
# - **epsilon** - $\varepsilon, E $
# - **zeta** - $\zeta, Z $
# - **eta** - $\eta, E $
# - **theta** - $\theta, T $
# - **iota** - $\iota, I $
# - **kappa** - $\kappa, K $
# - **lambda** - $\lambda, \Lambda $
# - **mu** - $\mu, M $
# - **nu** - $\nu, N $
# - **xi** - $\xi, \Xi $
# - **omicron** - $\omicron, O $
# - **pi** - $\pi, \Pi $
# - **rho** - $\rho, R $
# - **sigma** - $\sigma, \Sigma $
# - **sigma** - $\varsigma, \varSigma $
# - **tau** - $\tau, T $
# - **upsilon** - $\upsilon, \Upsilon $
# - **phi** - $\phi, \Phi $
# - **chi** - $\chi, C $
# - **psi** - $\psi, \Psi $
# - **omega** - $\omega, \Omega $
#
# ```
# - **alpha** - $\alpha, A $
# - **beta** - $\beta, B $
# - **gamma** - $\gamma, \Gamma $
# - **delta** - $\delta, \Delta $
# - **epsilon** - $\epsilon, E $
# - **epsilon** - $\varepsilon, E $
# - **zeta** - $\zeta, Z $
# - **eta** - $\eta, E $
# - **theta** - $\theta, T $
# - **iota** - $\iota, I $
# - **kappa** - $\kappa, K $
# - **lambda** - $\lambda, \Lambda $
# - **mu** - $\mu, M $
# - **nu** - $\nu, N $
# - **xi** - $\xi, \Xi $
# - **omicron** - $\omicron, O $
# - **pi** - $\pi, \Pi $
# - **rho** - $\rho, R $
# - **sigma** - $\sigma, \Sigma $
# - **sigma** - $\varsigma, \varSigma $
# - **tau** - $\tau, T $
# - **upsilon** - $\upsilon, \Upsilon $
# - **phi** - $\phi, \Phi $
# - **chi** - $\chi, C $
# - **psi** - $\psi, \Psi $
# - **omega** - $\omega, \Omega $
# ```

# %% [markdown]
# Intersections
#
# ```
# $L_C = L_A \cap (L_B \cup L_C)$
# ```
#
#
# $L_C = L_A \cap (L_B \cup L_C)$

# %% [markdown]
# Integral - $\int$
# ```$\int$```
#
#
# \begin{aligned}
# \textit{BF}[H_1 : H_2] &= \frac{p(\text{data}\mid \mu = m_0, \sigma^2 )}
#  {\int p(\text{data}\mid \mu, \sigma^2) p(\mu \mid m_0, \mathbf{n_0}, \sigma^2)\, d \mu} \\
# \textit{BF}[H_1 : H_2] &=\left(\frac{n + \mathbf{n_0}}{\mathbf{n_0}} \right)^{1/2} \exp\left\{-\frac 1 2 \frac{n }{n + \mathbf{n_0}} Z^2 \right\} \\
#  Z   &=  \frac{(\bar{Y} - m_0)}{\sigma/\sqrt{n}}
# \end{aligned}

# %% [markdown]
# Braces/Brackets
#
#
# $\left \{ \left \{ \{ | \} \right \} \right \}$
#
#
# Not working in jupyter
# ```
# \documentclass{article}
#  \begin{document}
#
# $\left \{ \left \{ \{ | \} \right \} \right \}$
#
# \delimiterfactor1100
# $Biggl(\left \{ \left \{ \{ | \} \right \} \right \})$
#
# \end{document}
# ```
#
# $\biggl(\left \{ \left \{ \{ )(x)(\biggr \} \right \} \right \})$
#
# ```
# $ Biggl(\biggl(\Bigl(\bigl((x)\bigr)\Bigr)\biggr)Biggr)$
# ```
#
# $ Biggl(\biggl(\Bigl(\bigl((x)\bigr)\Bigr)\biggr)Biggr)$
#
#
#  Scale the brackets to the size of the equation with ```\left [ (eq) \right ]```
#
# $\left [  P(A \cap B) = \frac{9}{15} + \frac{9}{15} - \frac{3}{15}= \frac{15}{15} = 1.0  \right ]$

# %% [markdown]
# infinity
# ```
# $\infty$
# ```
# $\infty$

# %% [markdown]
# triple equals:
# ```
# $\equiv$
# ```
# $\equiv$

# %% [markdown]
# Adding multiple cases within brackets/braces
# ```
# $  D_{it} =
#     \begin{cases}
#       1 & \text{if bank $i$ issues ABs at time $t$}\\
#       2 & \text{if bank $i$ issues CBs at time $t$}\\
#       0 & \text{otherwise}
#     \end{cases}
# $
# ```
# $
# \begin{equation}
#   D_{it} =
#     \begin{cases}
#       1 & \text{if bank $i$ issues ABs at time $t$}\\
#       2 & \text{if bank $i$ issues CBs at time $t$}\\
#       0 & \text{otherwise}
#     \end{cases}
# \end{equation}
# $
